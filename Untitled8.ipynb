# %% [markdown]
# <a href="https://colab.research.google.com/github/Antony12-PNG/ant60/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
# !python --version
# !apt-get install python3.12
# Out:
# ...
# Python 3.10.12
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# python3.12 is already the newest version (3.12.8-1+jammy1).
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.

# %%
import pandas as pd

df = pd.read_csv("/Llum")
df
# Out:
#      TEMPS  LLUM PATI  LLUM  A14  LLUM A23
# 0        1        253        146       134
# 1        2        157         74       103
# 2        3        253        147       137
# 3        4        246        130       100
# 4        5        246        140       141
# ..     ...        ...        ...       ...
# 175    176        254        155       103
# 176    177        254        148       163
# 177    178        254        155       104
# 178    179        254        124       131
# 179    180        254        175       129
#
# [180 rows x 4 columns]

# %%
from matplotlib import pyplot as plt
df['LLUM A23'].plot(kind='line', figsize=(8, 4), title='LLUM A23')
plt.gca().spines[['top', 'right']].set_visible(False)
#Aquesta grafica determina que la llum en l'aula A23 varia molt entre el rang 100 a 150, i que por arribar a baixar molt fins als 250, o fins i tot a pujar molt, om per exemple fis als 10

# %%
from matplotlib import pyplot as plt
df['LLUM  A14'].plot(kind='line', figsize=(8, 4), title='LLUM  A14')
plt.gca().spines[['top', 'right']].set_visible(False)
#L'aula A14 a diferencia de l'A23 la intensitat de la llum es troba entre els 100 fins als 175, pero que pot arribar a baixar quasi fins al zero.

# %%
from matplotlib import pyplot as plt
df['LLUM PATI'].plot(kind='line', figsize=(8, 4), title='LLUM PATI')
plt.gca().spines[['top', 'right']].set_visible(False)

#L'intensittat de la llum del pati es la més forta de las tres, ja que pot arribar fins als 250, i es pot mantindre estable en aquella inensitat, però pot arribar a baixar bastant

# %%
from matplotlib import pyplot as plt
df['TEMPS'].plot(kind='line', figsize=(8, 4), title='TEMPS')
plt.gca().spines[['top', 'right']].set_visible(False)
#El grafic de temps es mosttra lineal, ja que el temps es consecutiu, ja que ve del segon 1 fins al segon 180

# %%
max_u = df['LLUM PATI'].max()
print("El maxim de temperatura del patí és: ", max_u)
min_u = df['LLUM PATI'].min()
print("El mínim de temperatura del patí és:  ", min_u)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-26c4883a7297> in <cell line: 1>()
# ----> 1 max_u = df['LLUM PATI'].max()
#       2 print("El maxim de temperatura del patí és: ", max_u)
#       3 min_u = df['LLUM PATI'].min()
#       4 print("El mínim de temperatura del patí és:  ", min_u)
#
# NameError: name 'df' is not defined

# %%
max_dos = df['LLUM A14'].max()
print("El máxim de temperatura de l'aula A14 és: ", max_dos)
min_dos = df['LLUM A14'].min()
print("El mínim de temperatura de l'aula A14 és: ", min_dos)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-ec3aab4174ce> in <cell line: 1>()
# ----> 1 max_dos = df['LLUM A14'].max()
#       2 print("El máxim de temperatura de l'aula A14 és: ", max_dos)
#       3 min_dos = df['LLUM A14'].min()
#       4 print("El mínim de temperatura de l'aula A14 és: ", min_dos)
#
# NameError: name 'df' is not defined

# %%
max_tres = df['LLUM A23'].max()
print("El máxim de temperatura de l'aula A23 és: ",max_tres)
min_tres = df['LLUM A23'].min()
print("El máxim de temperatura de l'aula A23 és: ",min_tres)
# Out:
# El máxim de temperatura de l'aula A23 és:  254
# El máxim de temperatura de l'aula A23 és:  0

# %%
mitjana_un = df['LLUM PATI'].mean()
print(mitjana_un)
mitjana_dos = df['LLUM A14'].sum()/(len(df['LLUM A14']))
print(mitjana_dos)
mitjana_tres = df['LLUM A23'].mean()
print(mitjana_tres)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-816ef13e69e4> in <cell line: 1>()
# ----> 1 mitjana_un = df['LLUM PATI'].mean()
#       2 print(mitjana_un)
#       3 mitjana_dos = df['LLUM A14'].sum()/(len(df['LLUM A14']))
#       4 print(mitjana_dos)
#       5 mitjana_tres = df['LLUM A23'].mean()
#
# NameError: name 'df' is not defined
